# %% [markdown]
# #### Insurance Forecast
# - We will try to predict the individual medical costs billed by health insurance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Gerekli Kütüphanelerin Eklenmesi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Sütunlar Hakkında Genel Bilgi
#
# age: age of primary beneficiary
#
# sex: insurance contractor gender, female, male
#
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
#
# children: Number of children covered by health insurance / Number of dependents
#
# smoker: Smoking
#
# region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
#
# charges: Individual medical costs billed by health insurance
#
# *Can you accurately predict insurance costs?*

# %%
# df = pd.read_csv("C:\\Users\devri\Documents\GitHub\Global_AI_Hub_Proje\insurance.csv")
# df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# **Ben Jupyter Notebookta çalışıyorum o yüzden sizin kodu yoruma aldım.

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# **Veri kümemiz 1338 satır ve 7 sütundan oluşuyor.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# **Sex** sütunu hariç diğer bütün sütunlar sayısal değerler içeriyor.

# %%
df.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %% [markdown]
# **Veri kümemiz NaN değerler içermiyor.**

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
# **Children sütununda outlier olabilir çünkü std değeri mean değerinden büyük.**

# %% [markdown]
# ## Keşifsel Veri Analizi Yapılması

# %% [markdown]
# ### “smoker” (Sigara tüketen) ile “region”(Bölge) arasındaki ilişkiyi inceleyiniz.

# %%
df.groupby("region")["smoker"].value_counts()
# Out:
# region     smoker
# northeast  no        257
#            yes        67
# northwest  no        267
#            yes        58
# southeast  no        273
#            yes        91
# southwest  no        267
#            yes        58
# Name: smoker, dtype: int64

# %%
fig = sns.catplot(x="smoker", kind="count",hue = 'smoker', palette="viridis", data=df)
ax = fig.facet_axis(0, 0)

for c in ax.containers:
    labels = [f'{v.get_height()+0.2 }' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %% [markdown]
# **Toplamda 274 kişi sigara içerken, 1064 kişi sigara içmiyor.**

# %% [markdown]
# ###  ○ “bmi” ile “sex”(Cinsiyet) arasındaki ilişkiyi inceleyiniz.

# %%
df.groupby("sex")["bmi"].mean()
# Out:
# sex
# female    30.377749
# male      30.943129
# Name: bmi, dtype: float64

# %% [markdown]
# **Erkek katılımcıların ortalama bmi değerleri bayan katılımcılara göre daha yüksek.**

# %% [markdown]
# ### ○ “bmi” ile “children” arasındaki ilişkiyi inceleyiniz.

# %%
df.children.value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.groupby("children")["bmi"].mean()
# Out:
# children
# 0    30.550296
# 1    30.623148
# 2    30.978104
# 3    30.684331
# 4    31.391200
# 5    29.605000
# Name: bmi, dtype: float64

# %% [markdown]
# ### ○ En çok “children”’a sahip “region”’ı bulunuz.

# %%
df.groupby("region")["children"].count()
# Out:
# region
# northeast    324
# northwest    325
# southeast    364
# southwest    325
# Name: children, dtype: int64

# %% [markdown]
# **En çok 'children'a southeast region sahip**

# %%
fig = sns.catplot(x="region", kind="count",hue = 'children', palette="viridis", data=df, aspect=18/12)
ax = fig.facet_axis(0, 0)

for c in ax.containers:
    labels = [f'{(v.get_height()):}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
fig=sns.catplot(x="children", kind="count", palette="ch:.25", data=df, height = 6)
x = fig.facet_axis(0, 0)

# for c in ax.containers:
#     labels = [f'{v.get_height()}' for v in c]
#     ax.bar_label(c, labels=labels, label_type='edge')
plt.show()

# %% [markdown]
# ### ○ “Age” ile “bmi” arasındaki ilişkiyi inceleyiniz.

# %%
df.age.sample(15)
# Out:
# 935     59
# 1177    40
# 429     27
# 1063    36
# 82      22
# 641     42
# 294     25
# 674     44
# 1284    61
# 1210    36
# 16      52
# 6       46
# 829     39
# 374     20
# 592     20
# Name: age, dtype: int64

# %%
df.bmi.sample(15)
# Out:
# 328     33.800
# 351     25.600
# 268     30.200
# 678     36.100
# 188     32.200
# 401     47.520
# 341     30.020
# 436     31.730
# 882     22.135
# 291     29.640
# 889     33.630
# 77      35.530
# 1164    28.310
# 736     38.390
# 1129    18.600
# Name: bmi, dtype: float64

# %% [markdown]
# ### ○ “bmi” değişkeninde outlier var mıdır? İnceleyiniz.

# %%
# We can produce a function to get the number of outliers respectively each class. For the sake of practicality,
# we find the outliers for features without consideration of class distinction
# Interquartile Range 
def detect_outliers(df, col_name,tukey=1.5):
    ''' 
    this function detects outliers based on 1.5 time IQR and
    returns the number of lower and uper limit and number of outliers respectively
    '''
    first_quartile = np.percentile(np.array(df[col_name].tolist()), 25)
    third_quartile = np.percentile(np.array(df[col_name].tolist()), 75)
    IQR = third_quartile - first_quartile
                      
    upper_limit = third_quartile+(tukey*IQR)
    lower_limit = first_quartile-(tukey*IQR)
    outlier_count = 0
                      
    for value in df[col_name].tolist():
        if (value < lower_limit) | (value > upper_limit):
            outlier_count +=1
    return lower_limit, upper_limit, outlier_count

# %%
detect_outliers(df, "bmi")
# Out:
# (13.7, 47.290000000000006, 9)

# %% [markdown]
# **9 adet outlier olabilir.**

# %%
df[df["bmi"]>47.290000000000006]
# Out:
#       age     sex    bmi  children smoker     region      charges
# 116    58    male  49.06         0     no  southeast  11381.32540
# 286    46  female  48.07         2     no  northeast   9432.92530
# 401    47    male  47.52         1     no  southeast   8083.91980
# 543    54  female  47.41         0    yes  southeast  63770.42801
# 847    23    male  50.38         1     no  southeast   2438.05520
# 860    37  female  47.60         2    yes  southwest  46113.51100
# 1047   22    male  52.58         1    yes  southeast  44501.39820
# 1088   52    male  47.74         1     no  southeast   9748.91060
# 1317   18    male  53.13         0     no  southeast   1163.46270

# %%
df.bmi.mean()
# Out:
# 30.663396860986538

# %% [markdown]
# ### ○ “bmi” ile “charges” arasındaki ilişkiyi inceleyiniz.

# %%
df.groupby("bmi")["charges"].count()
# Out:
# bmi
# 15.960    1
# 16.815    2
# 17.195    1
# 17.290    3
# 17.385    1
#          ..
# 48.070    1
# 49.060    1
# 50.380    1
# 52.580    1
# 53.130    1
# Name: charges, Length: 548, dtype: int64

# %% [markdown]
# ### ○ “region”, “smoker” ve “bmi” arasındaki ilişkiyi bar plot kullanarak inceleyiniz.

# %%
df.groupby(["region", "smoker"])["bmi"].mean()
# Out:
# region     smoker
# northeast  no        29.332082
#            yes       28.565224
# northwest  no        29.212678
#            yes       29.140431
# southeast  no        33.442418
#            yes       33.096703
# southwest  no        30.507865
#            yes       31.005172
# Name: bmi, dtype: float64

# %%
sns.catplot(x="smoker", kind="count",hue = 'region', palette="viridis", data=df)
plt.show()
